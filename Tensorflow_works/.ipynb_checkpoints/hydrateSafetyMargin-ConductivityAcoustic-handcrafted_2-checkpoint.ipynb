# %%
# !pip install matplotlib-label-lines

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aa = pd.read_csv('D:\\Desktop Files\\weka data\\Dr Wiabu\\AA-NACL.csv',header=0,
                    names=['temp','conductivity','velocity','nacl','aa','aa1','aa2','nacl1','nacl2'],dtype='float32')
meg = pd.read_csv('D:\\Desktop Files\\weka data\\Dr Wiabu\\MEG-NACL.csv',header=0,
                    names=['temp','conductivity','velocity','nacl','meg','meg1','meg2','nacl1','nacl2'],dtype='float32')

# %%
aa

# %%
import mitosheet
mitosheet.sheet(aa, view_df=True)
# Out:
# MitoWidget(analysis_name='UUID-e068e5be-936d-4553-bac5-1c37f542f65a', code_json='{"imports": "from mitosheet i…

# %%
import lux
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-9dc1da9d19a2> in <module>
# ----> 1 import lux
#
# ModuleNotFoundError: No module named 'lux'

# %%
def getByTemp(df,t):
    aaZeroT = df.loc[df['temp'] == t]
    aaZeroNoT = aaZeroT.drop(['temp'], axis=1)
    return aaZeroNoT

# %%
# titanic_df[titanic_df['Survived']==1]['Survived']
def hydrateNaclCurvePred2(df,x,y,y1,y2,c,title,xlab,ylab,cv1,cv2,cv3):
    
    legend_prop = {'weight':'bold','size':20}
    
    plt.plot(df[x].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'gp-',linewidth=2, markersize=12, label =str(cv1)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'gp:',linewidth=2, markersize=12, label =str(cv2)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'gp--',linewidth=2, markersize=12, label =str(cv3)+'% '+str(c))
    
    plt.plot(df[x].where(df[c] == cv1).dropna(), df[y1].where(df[c] == cv1).dropna(),
             'bo-',linewidth=2, markersize=12, label =str(cv1)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv2).dropna(), df[y1].where(df[c] == cv2).dropna(),
             'bo:',linewidth=2, markersize=12, label =str(cv2)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv3).dropna(), df[y1].where(df[c] == cv3).dropna(),
             'bo--',linewidth=2, markersize=12, label =str(cv3)+'% '+str(c))
    
    plt.plot(df[x].where(df[c] == cv1).dropna(), df[y2].where(df[c] == cv1).dropna(),
             'mp-',linewidth=2, markersize=12, label =str(cv1)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv2).dropna(), df[y2].where(df[c] == cv2).dropna(),
             'mp:',linewidth=2, markersize=12, label =str(cv2)+'% '+str(c))
    plt.plot(df[x].where(df[c] == cv3).dropna(), df[y2].where(df[c] == cv3).dropna(),
             'mp--',linewidth=2, markersize=12, label =str(cv3)+'% '+str(c))
    
    plt.title(title, fontweight='bold',fontsize=15)
    plt.xlabel(xlab,fontsize=15)
    plt.ylabel(ylab,fontsize=15)
    plt.legend(prop=legend_prop)    
   


#  titanic_df[titanic_df['Survived']==1]['Survived']
def hydrateNaclCurvePred3(df,x,x1,x2,y,c,title,xlab,ylab,cv1,cv2,cv3):
    
    
    plt.plot(df[x].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'gp-',linewidth=2, markersize=15, label =str(cv1)+'wt%'+str(c)+ ' : EXP')
    plt.plot(df[x].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'gp:',linewidth=2, markersize=15,label =str(cv1)+'wt%'+str(c)+ ' : EXP')
    plt.plot(df[x].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'gp--',linewidth=2, markersize=15, label =str(cv1)+'wt%'+str(c)+ ' : EXP')

    plt.plot(df[x1].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'ms-',linewidth=2, markersize=10, label =str(cv2)+'wt%'+str(c)+ ' : ANN')
    plt.plot(df[x1].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'ms:',linewidth=2, markersize=10,label =str(cv2)+'wt%'+str(c)+ ' : ANN')
    plt.plot(df[x1].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'ms--',linewidth=2, markersize=10,label =str(cv2)+'wt%'+str(c)+ ' : ANN')    

    plt.plot(df[x2].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'bo-',linewidth=2, markersize=6, label =str(cv3)+'wt%'+str(c)+ ' : CBANN')
    plt.plot(df[x2].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'bo:',linewidth=2, markersize=6,label =str(cv3)+'wt%'+str(c)+ ' : CBANN')
    plt.plot(df[x2].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'bo--',linewidth=2, markersize=6,label =str(cv3)+'wt%'+str(c)+ ' : CBANN')
    

    legend_prop = {'weight':'bold','size':12}
    
    plt.title(title, fontweight='bold',fontsize=12)
    plt.xlabel(xlab,fontsize=15)
    plt.ylabel(ylab,fontsize=15)
    plt.legend(prop=legend_prop)    
   

#  titanic_df[titanic_df['Survived']==1]['Survived']
def hydrateNaclCurvePred4(df,x,x1,x2,y,c,title,xlab,ylab,cv1,cv2,cv3):
    
    
    l1 = plt.plot(df[x].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'k-',linewidth=2, markersize=15, label =str(cv1)+'wt% '+str(c))
    l2 = plt.plot(df[x].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'k:',linewidth=2, markersize=15,label =str(cv2)+'wt% '+str(c))
    l3 = plt.plot(df[x].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'k--',linewidth=2, markersize=15, label =str(cv3)+'wt% '+str(c))

    l4 = plt.plot(df[x1].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'gp-',linewidth=2, markersize=8, label =str(cv1)+'wt%'+str(c)+ ' : ANN')
    l5 = plt.plot(df[x1].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'ms:',linewidth=2, markersize=8,label =str(cv2)+'wt%'+str(c)+ ' : ANN')
    l6 = plt.plot(df[x1].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'bo--',linewidth=2, markersize=8,label =str(cv3)+'wt%'+str(c)+ ' : ANN')    

    plt.plot(df[x2].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             'bo-',linewidth=2, markersize=6, label =str(cv1)+'wt%'+str(c)+ ' : CBANN')
    plt.plot(df[x2].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             'bo:',linewidth=2, markersize=6,label =str(cv2)+'wt%'+str(c)+ ' : CBANN')
    plt.plot(df[x2].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             'bo--',linewidth=2, markersize=6,label =str(cv3)+'wt%'+str(c)+ ' : CBANN')
    

    legend_prop = {'weight':'bold','size':12}
    
    plt.title(title, fontweight='bold',fontsize=12)
    plt.xlabel(xlab,fontsize=15)
    plt.ylabel(ylab,fontsize=15)
#     plt.legend(prop=legend_prop) 
#     
#     legend1 = plt.legend((l1,l2,l3), [str(cv1)+'wt%',str(cv2)+'wt%',str(cv3)+'wt%'], loc='upper left')
#     plt.gca().add_artist(legend1)
#     plt.legend((l4,l5,l6),['EXP','ANN','CBANN'], loc='lower right')
    
#     plt.legend((l1,l2,l3), [str(cv1)+'wt%',str(cv2)+'wt%',str(cv3)+'wt%'], loc='upper left')
#     plt.legend((l4,l5,l6),['EXP','ANN','CBANN'], loc='lower right')
    
    lines = plt.gca().get_lines()
    include = [0,1,2]
    legend1 = plt.legend([lines[i] for i in include],[lines[i].get_label() for i in include], loc='upper left', prop=legend_prop)
    legend2 = plt.legend([lines[i] for i in [3,4,5]],['EXP','ANN','CBANN'], loc='lower right', prop=legend_prop)
    plt.gca().add_artist(legend1)

# upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

# %%
aaZeroNoT = getByTemp(aa,0)
aaNoT_4 = getByTemp(aa,4)
aaNoT_15 = getByTemp(aa,15)
aaNoT_25 = getByTemp(aa,25)

# %%
# FOR AA-NACL DATASET
plt.figure(figsize=(20, 25))
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
j = 1
tempt = ['0','4','15','25']
# vert = ['aa','aa1','aa2']
dataset = [aaZeroNoT,aaNoT_4,aaNoT_15,aaNoT_25]
# def hydrateNaclCurvePred3(df,x,x1,x2,y,c,title,xlab,ylab,cv1,cv2,cv3):
for i in range(4):
    plt.subplot(4,2,j)
    hydrateNaclCurvePred4(dataset[i],'nacl','nacl1','nacl2','velocity','aa',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Velocity',0.2,0.5,1)
    j = j + 1

# FOR CONDUCTIVITY
j = 5
for i in range(4):
    plt.subplot(4,2,j)
    hydrateNaclCurvePred4(dataset[i],'nacl','nacl1','nacl2','conductivity','aa',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Conductivity',1,1.5,2)
    j = j + 1

# %%
title='15c At Certain Constact NaCl'
xlab = 'AA'
ylab = 'Conductivity'
legend_prop = {'weight':'bold','size':10}

plt.plot(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : EXP', c='red')

plt.plot(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : ANN', c='green', marker='s')

plt.plot(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : CBANN', c='blue', marker='p')


# testing this
# plt.plot(pd.concat([aaNoT_15['aa'],aaNoT_15['aa1'],aaNoT_15['aa3']],axis=0).where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
# ].where(aaNoT_15['nacl'] == 3).dropna(),
#          'g-',linewidth=1, label =str('3')+'wt%'+str('nacl')+ ' : EXP')



plt.plot(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : EXP', c='red')

plt.plot(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : ANN', c='green', marker='s')

plt.plot(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : CBANN', c='blue', marker='p')

# testing this
# plt.plot(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
# ].where(aaNoT_15['nacl'] == 1).dropna(),
#          'g-',linewidth=1, label =str('1')+'wt%'+str('nacl')+ ' : EXP')


plt.plot(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : EXP', c='red')

plt.plot(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : ANN', c='green', marker='s')

plt.plot(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : CBANN', c='blue', marker='p')

# labelLines(plt.gca().get_lines(), align=False, color="k")
labelLines(plt.gca().get_lines(),align=False, zorder=2.5,yoffsets=2)


plt.title(title, fontweight='bold',fontsize=15)
plt.xlabel(xlab,fontsize=15)
plt.ylabel(ylab,fontsize=15)
plt.legend(prop=legend_prop)

# %%
title='15c At Certain Constact NaCl'
xlab = 'AA'
ylab = 'Conductivity'
legend_prop = {'weight':'bold','size':10}

l1 = plt.scatter(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : EXP', c='red', s=50)

l2 = plt.scatter(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : ANN', c='green', s=50, marker='s')

l3 = plt.scatter(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 3).dropna(),
         label =str('3')+'wt%'+str('nacl')+ ' : CBANN', c='blue', s=50, marker='p')


# testing this
# plt.plot(pd.concat([aaNoT_15['aa'],aaNoT_15['aa1'],aaNoT_15['aa3']],axis=0).where(aaNoT_15['nacl'] == 3).dropna(), aaNoT_15['conductivity'
# ].where(aaNoT_15['nacl'] == 3).dropna(),
#          'g-',linewidth=1, label =str('3')+'wt%'+str('nacl')+ ' : EXP')



plt.scatter(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : EXP', c='red', s=50)

plt.scatter(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : ANN', c='green', s=50, marker='s')

plt.scatter(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 1).dropna(),
         label =str('1')+'wt%'+str('nacl')+ ' : CBANN', c='blue', s=50, marker='p')

# testing this
# plt.plot(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 1).dropna(), aaNoT_15['conductivity'
# ].where(aaNoT_15['nacl'] == 1).dropna(),
#          'g-',linewidth=1, label =str('1')+'wt%'+str('nacl')+ ' : EXP')


l4 = plt.scatter(aaNoT_15['aa'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : EXP', c='red', s=50)

l5 = plt.scatter(aaNoT_15['aa1'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : ANN', c='green', s=50, marker='s')

l6 = plt.scatter(aaNoT_15['aa2'].where(aaNoT_15['nacl'] == 0).dropna(), aaNoT_15['conductivity'
].where(aaNoT_15['nacl'] == 0).dropna(),
         label =str('0')+'wt%'+str('nacl')+ ' : CBANN', c='blue', s=50, marker='p')

# labelLines(plt.gca().get_lines(), align=False, color="k")
# labelLines(plt.gca().get_lines(), zorder=2.5)
legend1 = plt.legend((l1,l2,l3), ['label1','label2','kkkkk'], loc='lower right')
plt.gca().add_artist(legend1)
plt.legend((l4,l5,l6),['label4','label5','jjjj'], loc='upper right')
# upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center

plt.title(title, fontweight='bold',fontsize=15)
plt.xlabel(xlab,fontsize=15)
plt.ylabel(ylab,fontsize=15)
# plt.legend(prop=legend_prop)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-61d5d0dc811f> in <module>
#      58 legend1 = plt.legend((l1,l2,l3), ['label1','label2','kkkkk'], loc='lower right')
#      59 plt.gca().add_artist(legend1)
# ---> 60 plt.legend((l4,l5,l6), loc='upper right')
#      61 # upper right
#      62 #       upper left
#
# ~\.conda\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2915 @_copy_docstring_and_deprecators(Axes.legend)
#    2916 def legend(*args, **kwargs):
# -> 2917     return gca().legend(*args, **kwargs)
#    2918
#    2919
#
# ~\.conda\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     282         .. plot:: gallery/text_labels_and_annotations/legend.py
#     283         """
# --> 284         handles, labels, extra_args, kwargs = mlegend._parse_legend_args(
# ...

# %%
def hydrateScatterPlot(df,x,x1,x2,y,c,title,xlab,ylab,cv1,cv2,cv3):
    
    plt.scatter(df[x].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             c='red', s=50, label ='EXP')
    plt.scatter(df[x1].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             c='green', s=50, marker='s', label ='ANN')
    plt.scatter(df[x2].where(df[c] == cv1).dropna(), df[y].where(df[c] == cv1).dropna(),
             c='blue', s=50, marker='p', label ='CBANN')

    
    plt.scatter(df[x].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             c='red', s=50)
    plt.scatter(df[x1].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             c='green', s=50, marker='s')
    plt.scatter(df[x2].where(df[c] == cv2).dropna(), df[y].where(df[c] == cv2).dropna(),
             c='blue', s=50, marker='p')

    
    plt.scatter(df[x].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             c='red', s=50)
    plt.scatter(df[x1].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             c='green', s=50, marker='s')
    plt.scatter(df[x2].where(df[c] == cv3).dropna(), df[y].where(df[c] == cv3).dropna(),
             c='blue', s=50, marker='p')

    legend_prop = {'weight':'bold','size':10}
    
    plt.title(title, fontweight='bold',fontsize=20)
    plt.xlabel(xlab,fontsize=15)
    plt.ylabel(ylab,fontsize=15)
#     plt.legend(bbox_to_anchor=(0.5, 0.7), ncol=1,fancybox=True, loc='upper center',prop=legend_prop)
    plt.legend(bbox_to_anchor=(0.3, 0.9), ncol=1,fancybox=True, loc='right',prop=legend_prop)

# %%
# FOR AA-NACL DATASET
plt.figure(figsize=(20, 25))
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
j = 1
tempt = ['0','4','15','25']
vert = ['aa','aa1','aa2']
dataset = [aaZeroNoT,aaNoT_4,aaNoT_15,aaNoT_25]
for i in range(4):
    plt.subplot(4,2,j)
    hydrateScatterPlot(dataset[i],'nacl','nacl1','nacl2','velocity','aa',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Velocity',1,1.5,2)
    j = j + 1

# FOR CONDUCTIVITY
j = 5
for i in range(4):
    plt.subplot(4,2,j)
    hydrateScatterPlot(dataset[i],'nacl','nacl1','nacl2','conductivity','aa',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Conductivity',1,1.5,2)
    j = j + 1

# %%
megNoT_15 = getByTemp(meg,15)
megNoT_25 = getByTemp(meg,25)

# %%
# FOR AA-NACL DATASET
plt.figure(figsize=(15, 25))
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
j = 1
tempt = ['15','25']
vert = ['meg','meg1','meg2']
dataset = [megNoT_15,megNoT_25]
for i in range(2):
    plt.subplot(4,2,j)
    hydrateNaclCurvePred4(dataset[i],'nacl','nacl1','nacl2','velocity','meg',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Velocity',0,10,20)
#         hydrateScatterPlot(dataset[i],'aa','aa1','aa2','velocity','nacl',tempt[i]+'c At Certain Constact NaCl'
#                  ,'AA','Velocity',3,1,0)
    j = j + 1

# FOR CONDUCTIVITY
j = 3
for i in range(2):
    plt.subplot(4,2,j)
    hydrateNaclCurvePred4(dataset[i],'nacl','nacl1','nacl2','conductivity','meg',tempt[i]+'\u00B0C'
                 ,'NaCl Concentration','Conductivity',0,10,20)
    j = j + 1

# %%
meg
# Out:
#     temp  conductivity     velocity  nacl   meg       meg1       meg2  nacl1  \
# 0   15.0      0.050000  1465.650024   0.0   0.0   0.100000   0.020000   0.00
# 1   15.0      0.050000  1518.579956   0.0  10.0  10.050000  10.110000   0.09
# 2   15.0      0.050000  1571.040039   0.0  20.0  19.500000  20.000000   0.05
# 3   15.0      0.050000  1621.489990   0.0  30.0  30.250000  30.150000   0.18
# 4   15.0      0.050000  1665.000000   0.0  40.0  40.099998  39.980000   0.07
# 5   15.0     13.880000  1477.719971   1.0   0.0   0.100000   0.050000   1.10
# 6   15.0     10.320000  1529.209961   1.0  10.0  10.210000   9.950000   0.81
# 7   15.0      7.470000  1580.930054   1.0  20.0  19.020000  20.059999   1.00
# 8   15.0      5.230000  1630.430054   1.0  30.0  28.400000  29.889999   1.10
# 9   15.0      3.580000  1672.760010   1.0  40.0  40.180000  40.060001   1.20
# 10  15.0     38.240002  1500.890015   3.0   0.0   0.000000   0.000000   3.11
# ...

# %%
# FOR AA-NACL DATASET
plt.figure(figsize=(15, 25))
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
j = 1
tempt = ['15','25']
vert = ['meg','meg1','meg2']
dataset = [megNoT_15,megNoT_25]
for i in range(2):
    plt.subplot(4,2,j)
    hydrateScatterPlot(dataset[i],'meg','meg1','meg2','velocity','nacl',tempt[i]+'\u00B0C'
                 ,'MEG Concentration','Velocity',0,1,3)
#         hydrateScatterPlot(dataset[i],'aa','aa1','aa2','velocity','nacl',tempt[i]+'c At Certain Constact NaCl'
#                  ,'AA','Velocity',3,1,0)
    j = j + 1

# FOR CONDUCTIVITY
j = 3
for i in range(2):
    plt.subplot(4,2,j)
    hydrateScatterPlot(dataset[i],'meg','meg1','meg2','conductivity','nacl',tempt[i]+'\u00B0C'
                 ,'MEG Concentration','Conductivity',0,1,3)
    j = j + 1

# %%
megNoT_15
# Out:
#     conductivity     velocity  nacl   meg       meg1       meg2  nacl1  nacl2
# 0       0.050000  1465.650024   0.0   0.0   0.100000   0.020000   0.00   0.00
# 1       0.050000  1518.579956   0.0  10.0  10.050000  10.110000   0.09   0.04
# 2       0.050000  1571.040039   0.0  20.0  19.500000  20.000000   0.05   0.01
# 3       0.050000  1621.489990   0.0  30.0  30.250000  30.150000   0.18   0.12
# 4       0.050000  1665.000000   0.0  40.0  40.099998  39.980000   0.07   0.00
# 5      13.880000  1477.719971   1.0   0.0   0.100000   0.050000   1.10   0.99
# 6      10.320000  1529.209961   1.0  10.0  10.210000   9.950000   0.81   1.06
# 7       7.470000  1580.930054   1.0  20.0  19.020000  20.059999   1.00   1.00
# 8       5.230000  1630.430054   1.0  30.0  28.400000  29.889999   1.10   1.01
# 9       3.580000  1672.760010   1.0  40.0  40.180000  40.060001   1.20   1.00
# 10     38.240002  1500.890015   3.0   0.0   0.000000   0.000000   3.11   3.05
# ...

# %%
import mitosheet
mitosheet.sheet(megNoT_15, view_df=True)
# Out:
# MitoWidget(analysis_name='UUID-afac77ea-6219-4286-a043-8122d36887cb', code_json='{"imports": "from mitosheet i…

# %%
# MITO CODE START (DO NOT EDIT)

from mitosheet import * # Import necessary functions from Mito
register_analysis('UUID-afac77ea-6219-4286-a043-8122d36887cb') # Let Mito know which analysis is being run

# Pivoted megNoT_15 into df2
df2 = pd.DataFrame(data={})

  
# MITO CODE END (DO NOT EDIT)

# %%
# Special more simple code to plot those graph
# df.pivot('Hour', 'Group', 'Count').plot(kind='line', marker='o')

# Special more simple code to plot those graph
megNoT_15.pivot('meg', 'nacl', 'conductivity').plot(kind='bar')
megNoT_25.pivot('nacl', 'meg', 'conductivity').plot(kind='bar')

# sns.barplot(y='conductivity',x='meg',hue='nacl',data=megNoT_15);
# Out:
# <AxesSubplot:xlabel='nacl'>

# %%
sns.barplot(y='conductivity',x='meg',hue='nacl',data=megNoT_15)
# sns.barplot(y='conductivity',x='meg1',hue='nacl1',data=megNoT_15)

# sort_wine_more_than_mean = wine_more_than_mean.sort_values('wine_servings',ascending=False)

# top5_alcohol = df.sort_values('total_litres_of_pure_alcohol',
#                               ascending=False)[:5].reset_index(drop=True)


def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)


fig, ax = plt.subplots(figsize=(10,16))
fig.tight_layout(pad=2)

plt.subplot(3,1,1)
sns.set_style('whitegrid')
ax = sns.barplot(y='nacl',x='velocity',hue='meg',data=megNoT_15, saturation=.5)
ax = sns.barplot(y='nacl1',x='velocity',hue='meg1',data=megNoT_15, palette='prism')
ax = sns.barplot(y='nacl2',x='velocity',hue='meg2',data=megNoT_15)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 7), textcoords='offset points',fontsize=12,rotation=90)
change_width(ax, .40)
plt.title('EXP Meg Graph at 15 deg', fontsize=15)
# plt.xlabel('MEG', fontsize=15)
plt.xticks(fontsize=10, rotation=90)
# plt.ylabel('velocity', fontsize=15)
plt.yticks(fontsize=15)
sns.despine(bottom=True)
ax.grid(True)

plt.subplot(3,1,2)
sns.set_style('whitegrid')
ax = sns.barplot(y='nacl1',x='velocity',hue='meg1',data=megNoT_15,palette='prism')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 7), textcoords='offset points',fontsize=12,rotation=90)
change_width(ax, .40)
plt.title('CBANN Meg Graph at 15 deg', fontsize=15)
# plt.xlabel('MEG', fontsize=15)
plt.xticks(fontsize=10, rotation=90)
# plt.ylabel('velocity', fontsize=15)
plt.yticks(fontsize=15)
# sns.despine(bottom=True)
ax.grid(True)


plt.subplot(3,1,3)

sns.set_style('whitegrid')
ax = sns.barplot(y='nacl2',x='velocity',hue='meg2',data=megNoT_15)

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.1f'),
                (p.get_x() + p.get_width(), p.get_height()),
                ha='center', va='center',
                xytext=(0, 7), textcoords='offset points',fontsize=12, rotation=90)
change_width(ax, .40)
plt.title('ANN Meg Graph at 15 deg', fontsize=15)
# plt.xlabel('MEG', fontsize=15)
plt.xticks(fontsize=10, rotation=90)
# plt.ylabel('velocity', fontsize=15)
plt.yticks(fontsize=15)
# sns.despine(bottom=True)
ax.grid(True)



# sns.set_style('ticks')
# ax = sns.barplot(y='conductivity',x='meg',hue='nacl',data=megNoT_15)
# # ax = sns.barplot(y='conductivity',x='meg',hue='nacl',data=megNoT_25,palette='Wistia')

# plt.title('TOP5 countries by pure alcohol consumption', fontsize=30)
# plt.xlabel(None)
# plt.xticks(fontsize=15, rotation=30)
# plt.ylabel('Litres per person', fontsize=25)
# plt.yticks(fontsize=15)
# sns.despine(bottom=True)
# ax.grid(False)
# ax.tick_params(bottom=False, left=True)
# for _,s in ax.spines.items():
#     s.set_color('black')
plt.show()

# %%
megNoT_25
# Out:
#     conductivity     velocity  nacl   meg       meg1       meg2  nacl1  nacl2
# 20      0.050000  1496.869995   0.0   0.0   0.100000   0.020000   0.00   0.00
# 21      0.050000  1541.410034   0.0  10.0  10.050000  10.110000   0.09   0.04
# 22      0.050000  1585.170044   0.0  20.0  19.500000  20.000000   0.05   0.01
# 23      0.050000  1627.000000   0.0  30.0  30.250000  30.150000   0.18   0.12
# 24      0.050000  1662.250000   0.0  40.0  40.099998  39.980000   0.07   0.00
# 25     17.280001  1507.869995   1.0   0.0   0.100000   0.050000   1.10   0.99
# 26     13.030000  1551.400024   1.0  10.0  10.210000   9.950000   0.81   1.06
# 27      9.610000  1595.489990   1.0  20.0  19.020000  20.059999   1.00   1.00
# 28      6.830000  1634.410034   1.0  30.0  28.400000  29.889999   1.10   1.01
# 29      4.760000  1669.989990   1.0  40.0  40.180000  40.060001   1.20   1.00
# 30     47.349998  1528.050049   3.0   0.0   0.000000   0.000000   3.11   3.05
# ...

# %%
# megNoT_15_c['f']=(megNoT_15['nacl']==megNoT_15['nacl1']) & (megNoT_15['nacl']==megNoT_15['nacl2'])

# megNoT_15_c=megNoT_15.where(megNoT_15['nacl']==megNoT_15['nacl1']).dropna()
# megNoT_15_c=megNoT_15_c.loc[0:7,]
# megNoT_15_c

megNoT_25_c=megNoT_25.where(megNoT_25['nacl']==megNoT_25['nacl1']).dropna()
megNoT_25_c=megNoT_25_c.loc[0:27,]
megNoT_25_c
# Out:
#     conductivity     velocity  nacl   meg   meg1       meg2  nacl1  nacl2
# 20          0.05  1496.869995   0.0   0.0   0.10   0.020000    0.0    0.0
# 27          9.61  1595.489990   1.0  20.0  19.02  20.059999    1.0    1.0

# %%
# megNoT_15_c
megNoT_15_v=megNoT_15_c[['velocity','meg','meg1','meg2']]
megNoT_15_v=megNoT_15_v.rename({'meg':'EXP','meg1':'ANN','meg2':'CBANN'}, axis=1)
megNoT_15_v

# megNoT_15_c
megNoT_15_vc=megNoT_15_c[['conductivity','meg','meg1','meg2']]
megNoT_15_vc=megNoT_15_vc.rename({'meg':'EXP','meg1':'ANN','meg2':'CBANN'}, axis=1)
megNoT_15_vc


def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)



plt.figure(figsize=(15, 25))
# plt.rcParams["font.weight"] = "bold"
# plt.rcParams["axes.labelweight"] = "bold"
j = 1
tempt = ['15','25']
vert = ['meg','meg1','meg2']
dataset = [megNoT_15,megNoT_25]
for i in range(2):
    plt.subplot(4,2,j)
    hydrateScatterPlot(dataset[i],'meg','meg1','meg2','velocity','nacl',tempt[i]+'\u00B0C'
                 ,'MEG Concentration','Velocity',0,1,3)
#         hydrateScatterPlot(dataset[i],'aa','aa1','aa2','velocity','nacl',tempt[i]+'c At Certain Constact NaCl'
#                  ,'AA','Velocity',3,1,0)
    j = j + 1


def plotbar(df,x,y,y1,y2,c,title):
    df=df[[x,y,y1,y2]]
    df=df.rename({y:'EXP',y1:'ANN',y2:'CBANN'}, axis=1)
    df
    dfff = pd.melt(df, id_vars=x, var_name=c, value_name=y)
#     sns.catplot(x=x,y=y,hue=c,data=dfff, kind='bar')
#     fig, ax = plt.subplots(figsize=(5,14))
#     fig.tight_layout(pad=2)

#     plt.subplot(1,2,1)
    sns.set_style('whitegrid')
    # ax = sns.barplot(y='nacl',x='velocity',hue='meg',data=megNoT_15, saturation=.5)
    ax = sns.barplot(x=x,y=y,hue=c,data=dfff)

    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.1f'),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center',
                    xytext=(0, 7), textcoords='offset points',fontsize=12,rotation=90)
#     change_width(ax, .30)
    plt.title(title, fontsize=15)
    plt.xlabel(y, fontsize=15)
    plt.xticks(fontsize=10, rotation=90)
    plt.ylabel(x, fontsize=15)
    plt.yticks(fontsize=15)
    sns.despine(bottom=True)
    ax.grid(True)

# %%
j = 1
tempt = ['15','25']
vert = ['meg','meg1','meg2']
dataset = [megNoT_15,megNoT_25]
fig, ax = plt.subplots(figsize=(5,14))
fig.tight_layout(pad=2)

plt.subplot(1,2,j)

plotbar(megNoT_15_c,'conductivity','meg','meg1','meg2','nacl',y+' graph at 15\u00B0C with '+c+' constant')

# %%
dfff = pd.melt(megNoT_15_v, id_vars='velocity', var_name='nacl', value_name='meg')
dffff = pd.melt(megNoT_15_vc, id_vars='conductivity', var_name='nacl', value_name='meg')

dfff
# Out:
#       velocity   nacl        meg
# 0  1465.650024    EXP   0.000000
# 1  1580.930054    EXP  20.000000
# 2  1465.650024    ANN   0.100000
# 3  1580.930054    ANN  19.020000
# 4  1465.650024  CBANN   0.020000
# 5  1580.930054  CBANN  20.059999

# %%
sns.catplot(x='velocity',y='meg',hue='nacl',data=dfff, kind='bar')

sns.catplot(x='conductivity',y='meg',hue='nacl',data=dffff, kind='bar')

# %%
import jupyterthemes as jt
# !jt -t oceans16
# !jt -r
# Available themes:
# onedork grade3 oceans16 chesterish monokai solarizedl solarizedd

# List of available Palettes 
import matplotlib.cm as cm
maps=[m for m in cm.datad if not m.endswith("_r")]
print(maps)
# Out:
# ['Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c']
