# %%
import FATS
# Out:
# Traceback (most recent call last):
#
#   File "C:\Program Data\envs\Tensorflow\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-2a484572a385>", line 1, in <module>
#     import FATS
#
#   File "C:\Program Data\envs\Tensorflow\lib\site-packages\FATS\__init__.py", line 2, in <module>
#     from .Feature import FeatureSpace
#
#   File "C:\Program Data\envs\Tensorflow\lib\site-packages\FATS\Feature.py", line 93
#     print "Warning: the feature", name, "could not be calculated because", obj().Data, "are needed."
#                                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
# df_columns[0:5]
# Out:
# ['@ATTRIBUTE 0_FFT mean coefficient_0 NUMERIC',
#  '@ATTRIBUTE 0_FFT mean coefficient_1 NUMERIC',
#  '@ATTRIBUTE 0_FFT mean coefficient_2 NUMERIC',
#  '@ATTRIBUTE 0_FFT mean coefficient_3 NUMERIC',
#  '@ATTRIBUTE 0_FFT mean coefficient_4 NUMERIC']

# %%
dff_columns = pd.DataFrame(df_columns)
dff_columns.head()

dff_columns.to_csv('D:\\desktop files\\weka\\Datasets\\HAPT Data Set\\hapt_tsfel_train_ft_selected_and_label_columns.csv')

# %%
# Load data
# x_train_sig = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_train.txt', dtype='float32')
# x_test_sig = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_test.txt', dtype='float32')

# x_train_sig = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_train.txt')
# x_test_sig = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_test.txt')
# y_test = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_y_test.txt')
# y_train = np.loadtxt('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_y_train.txt')

x_train_sig = pd.read_csv('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_train.txt')
x_test_sig = pd.read_csv('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_X_test.txt')
y_test = pd.read_csv('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_y_test.txt')
y_train = pd.read_csv('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\final_y_train.txt')

# %%
features = pd.read_csv('D:\\desktop files\\weka\\Datasets\\Ambient_uci\\features.txt', header=None)

# %%
# y_train.shape
# x_train_sig.info()
# x_test_sig.info()
y_train


# features.info()
# Out:
#       1
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 4246  6
# 4247  6
# 4248  6
# 4249  6
# 4250  6
#
# [4251 rows x 1 columns]

# %%
x_train = x_train_sig
x_test = x_test_sig

# %%
# y_train = pd.DataFrame(y_train)

# %%
activities = y_train
lab = []

# for n in activities:
#     lab =lab + str(activities.replace(1,'WALKING'))
#     lab = lab + str(activities.replace(2,'WALKING_UPSTAIRS'))
#     lab = lab + str(activities.replace(3,'WALKING_DOWNSTAIRS'))
#     lab = lab + str(activities.replace(4,'SITTING'))
#     lab = lab + str(activities.replace(5,'STANDING'))
#     lab = lab + str(activities.replace(6,'LAYING'))

for n in activities:
    lab.append(activities.replace(1,'WALKING')
    lab.append(activities.replace(2,'WALKING_UPSTAIRS')
    lab.append(activities.replace(3,'WALKING_DOWNSTAIRS')
    lab.append(activities.replace(4,'SITTING')
    lab.append(activities.replace(5,'STANDING')
    lab.append(activities.replace(6,'LAYING')
# Out:
#   File "<ipython-input-74-953333973650>", line 14
#     lab.append(activities.replace(2,'WALKING_UPSTAIRS')
#       ^
# SyntaxError: invalid syntax

# %%
lab1 = []
for i in lab:
    lab1.append(i)
# lab1 = pd.DataFrame(lab)
# lab1

# %%
lab1
# Out:
# [' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '1',
#  '\n',
#  '0',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'W',
#  'A',
#  'L',
#  'K',
#  'I',
#  'N',
#  'G',
#  '\n',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'W',
#  'A',
#  'L',
#  'K',
#  'I',
#  'N',
#  'G',
#  '\n',
#  '2',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'W',
#  'A',
#  'L',
#  'K',
#  'I',
#  'N',
#  'G',
#  '\n',
#  '3',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'W',
#  'A',
#  'L',
#  'K',
#  'I',
#  'N',
#  'G',
#  '\n',
#  '4',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'W',
#  'A',
#  'L',
#  'K',
#  'I',
#  'N',
#  'G',
#  '\n',
#  '.',
#  '.',
#  '.',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  '\n',
#  '4',
#  '2',
#  '4',
#  '6',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '6',
#  '\n',
#  '4',
#  '2',
#  '4',
#  '7',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
# ...

# %%
# labels = np.concatenate([y_train, y_test])
labels = y_train
disc_labels = []
for l in labels:
  if l == 1:
    disc_labels.append('WALKING')
  elif l == 2:
    disc_labels.append('WALKING_UPSTAIRS')
  elif l == 3:
    disc_labels.append('WALKING_DOWNSTAIRS')
  elif l == 4:
    disc_labels.append('SITTING')
  elif l == 5:
    disc_labels.append('STANDING')
  elif l == 6:
    disc_labels.append('LAYING')

print(disc_labels)
#   elif l == 7:
#     disc_labels.append('STAND_TO_SIT')
#   elif l == 8:
#     disc_labels.append('SIT_TO_STAND')    
#   elif l == 9:
#     disc_labels.append('SIT_TO_LIE')
#   elif l == 10:
#     disc_labels.append('LIE_TO_SIT')    
#   elif l == 11:
#     disc_labels.append('STAND_TO_LIE')    
#   elif l == 12:
#     disc_labels.append('LIE_TO_STAND')
# Out:
# []

# %%
labels
# disc_labels
# y_train = pd.DataFrame(disc_labels)
# Out:
#       1
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ...  ..
# 4246  6
# 4247  6
# 4248  6
# 4249  6
# 4250  6
#
# [4251 rows x 1 columns]

# %%
y_train.head()
# Out:
#    1
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
disc_labels
# Out:
# []

# %%
features
# featuresT = features.T
# Out:
#                                             0
# 0                         1 tBodyAcc-mean()-X
# 1                         2 tBodyAcc-mean()-Y
# 2                         3 tBodyAcc-mean()-Z
# 3                          4 tBodyAcc-std()-X
# 4                          5 tBodyAcc-std()-Y
# ..                                        ...
# 556      557 angle(tBodyGyroMean-gravityMean)
# 557  558 angle(tBodyGyroJerkMean-gravityMean)
# 558                  559 angle(X-gravityMean)
# 559                  560 angle(Y-gravityMean)
# 560                  561 angle(Z-gravityMean)
#
# [561 rows x 1 columns]

# %%
x_train.columns = features

# %%
x_train
# Out:
#       (tBodyAcc-Mean-1                ,)  (tBodyAcc-Mean-2                ,)  \
# 0                               0.043580                           -0.005970
# 1                               0.039480                           -0.002131
# 2                               0.039978                           -0.005153
# 3                               0.039785                           -0.011809
# 4                               0.038758                           -0.002289
# ...                                  ...                                 ...
# 7762                            0.048048                           -0.042445
# 7763                            0.037639                            0.006430
# 7764                            0.037451                           -0.002724
# 7765                            0.044011                           -0.004536
# 7766                            0.068954                            0.001810
#
# ...

# %%
x_train.to_csv('D:\\desktop files\\weka\\Datasets\\HAPT Data Set\\hapt_x_train.txt')

# %%
ft =[]

for index,i in enumerate(features[0]):
    print('@ATTRIBUTE ' + str(i) + ' NUMERIC')
#     ft.append(i)
# Out:
# @ATTRIBUTE tBodyAcc-Mean-1                 NUMERIC
# @ATTRIBUTE tBodyAcc-Mean-2                 NUMERIC
# @ATTRIBUTE tBodyAcc-Mean-3                 NUMERIC
# @ATTRIBUTE tBodyAcc-STD-1                  NUMERIC
# @ATTRIBUTE tBodyAcc-STD-2                  NUMERIC
# @ATTRIBUTE tBodyAcc-STD-3                  NUMERIC
# @ATTRIBUTE tBodyAcc-Mad-1                  NUMERIC
# @ATTRIBUTE tBodyAcc-Mad-2                  NUMERIC
# @ATTRIBUTE tBodyAcc-Mad-3                  NUMERIC
# @ATTRIBUTE tBodyAcc-Max-1                  NUMERIC
# @ATTRIBUTE tBodyAcc-Max-2                  NUMERIC
# @ATTRIBUTE tBodyAcc-Max-3                  NUMERIC
# @ATTRIBUTE tBodyAcc-Min-1                  NUMERIC
# @ATTRIBUTE tBodyAcc-Min-2                  NUMERIC
# @ATTRIBUTE tBodyAcc-Min-3                  NUMERIC
# @ATTRIBUTE tBodyAcc-SMA-1                  NUMERIC
# @ATTRIBUTE tBodyAcc-Energy-1               NUMERIC
# @ATTRIBUTE tBodyAcc-Energy-2               NUMERIC
# ...

# %%
x_train = pd.concat([x_train, y_train], axis=1)

# %%
x_train
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.043580 -0.005970 -0.035054 -0.995381 -0.988366 -0.937382 -0.995007
# 1     0.039480 -0.002131 -0.029067 -0.998348 -0.982945 -0.971273 -0.998702
# 2     0.039978 -0.005153 -0.022651 -0.995482 -0.977314 -0.984760 -0.996415
# 3     0.039785 -0.011809 -0.028916 -0.996194 -0.988569 -0.993256 -0.996994
# 4     0.038758 -0.002289 -0.023863 -0.998241 -0.986774 -0.993115 -0.998216
# ...        ...       ...       ...       ...       ...       ...       ...
# 7762  0.048048 -0.042445 -0.065884 -0.195448 -0.278326 -0.219954 -0.282233
# 7763  0.037639  0.006430 -0.044345 -0.235372 -0.302680 -0.232843 -0.322483
# 7764  0.037451 -0.002724  0.021009 -0.218281 -0.378082 -0.076950 -0.304446
# 7765  0.044011 -0.004536 -0.051242 -0.219202 -0.383350 -0.081035 -0.310419
# 7766  0.068954  0.001810 -0.080323 -0.269336 -0.366553 -0.147294 -0.377332
#
# ...

# %%
x_train.to_csv('D:\\desktop files\\weka\\Datasets\\HAPT Data Set\\hapt_x_train_label.txt',index=False)

# %%
import matplotlib.pyplot as plt

# %%
ig = {'ft': [100,90,80,70,60,50,40,30,20,10],
        'a': [90.7,90.5,90.6,90.9,89.6,70.9,70.3,70.8,63.8,62.9]
       } 
ig_df = pd.DataFrame(ig,columns=['ft','a']) 

cr = {'ft': [100,90,80,70,60,50,40,30,20,10],
        'a': [79.8,79.9,78.6,77.5,77.1,76.5,74.4,70.6,66.3,58.3]
       } 
cr_df = pd.DataFrame(cr,columns=['ft','a'])

rff = {'ft': [100,90,80,70,60,50,40,30,20,10],
        'a': [92.9,93.2,93.6,93.0,92.7,91.8,92.2,91.2,89.9,87.4]
       } 
rff_df = pd.DataFrame(rff,columns=['ft','a'])

gr = {'ft': [100,90,80,70,60,50,40,30,20,10],
        'a': [77.0,75.4,70.6,71.7,64.9,61.8,59.4,58.2,55.5,45.6]
       } 
gr_df = pd.DataFrame(gr,columns=['ft','a'])

chi = {'ft': [100,90,80,70,60,50,40,30,20,10],
        'a': [92.5,92.7,92.7,92.8,89.6,89.0,89.6,70.0,68.9,68.5]
       } 
chi_df = pd.DataFrame(chi,columns=['ft','a'])

# %%
plt.figure(figsize=(10, 7))
plt.plot(ig_df['ft'], ig_df['a'], c='red', label='InfoGain')
plt.plot(cr_df['ft'], cr_df['a'], c='green', label='Correlation')
plt.plot(rff_df['ft'], rff_df['a'], c='blue', label='Relief')
plt.plot(gr_df['ft'], gr_df['a'], c='orange', label='Gain Ratio')
plt.plot(chi_df['ft'], chi_df['a'], c='yellow', label='Chi Square')

plt.title('Decision Tree Accuracy Against Features Graph')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Graphs

# %%
df_sig = pd.read_csv('D:\\desktop files\\weka\\Datasets\\HAPT Data Set\\uci_4fts_selectors\\ft_selectors_report1.csv')
df_sig
# Out:
#    features  bn_ig  bn_cr  bn_rff  bn_gr  bn_chi  knn_ig  knn_cr  knn_rff  \
# 0       100   76.0   59.1    84.1   56.5    81.1    92.2    86.3     95.2
# 1        90   77.2   58.6    84.6    NaN    82.0    92.0    85.9     95.4
# 2        80   78.7   58.3    84.8   53.4    81.9    92.2    85.4     95.8
# 3        70   79.9   57.7    86.0   52.5    82.4    92.0    85.0     95.6
# 4        60   73.6   56.6    84.9   48.0    78.8    90.4    84.7     96.1
# 5        50   59.0   56.1    84.8   47.6    69.4    71.6    84.1     95.6
# 6        40   57.1   54.5    84.9   46.6    69.4    70.3    82.4     95.6
# 7        30   57.5   52.3    84.7   45.6    58.7    72.6    79.5     95.1
# 8        20   54.8   53.9    82.3   43.7    57.2    64.0    72.0     91.1
# 9        10   52.6   52.1    81.4   37.9    58.1    62.2    58.7     86.5
#
#    knn_gr  ...  rt_ig  rt_cr  rt_rff  rt_gr  rt_chi  dt_ig  dt_cr  dt_rff  \
# 0    73.2  ...   86.5   75.2    91.1   69.9    89.0   90.7   79.8    92.9
# ...

# %%
plt.figure(figsize=(20, 30))

plt.subplot(3,2,1)
plt.plot(df_sig['features'], df_sig['dt_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['dt_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['dt_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['dt_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['dt_chi'], c='yellow', label='Chi Square')
plt.title('Decision Tree Accuracy Against Features Graph')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(3,2,2)
plt.plot(df_sig['features'], df_sig['bn_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['bn_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['bn_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['bn_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['bn_chi'], c='yellow', label='Chi Square')
plt.title('BayesNet Accuracy Against Features Graph of each classifier')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(3,2,3)
plt.plot(df_sig['features'], df_sig['knn_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['knn_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['knn_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['knn_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['knn_chi'], c='yellow', label='Chi Square')
plt.title('KNN Accuracy Against Features Graph of each classifier')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(3,2,4)
plt.plot(df_sig['features'], df_sig['cvr_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['cvr_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['cvr_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['cvr_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['cvr_chi'], c='yellow', label='Chi Square')
plt.title('\n ClassificationViaRegression Accuracy \n Against Features Graph of each classifier')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(3,2,5)
plt.plot(df_sig['features'], df_sig['rf_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['rf_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['rf_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['rf_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['rf_chi'], c='yellow', label='Chi Square')
plt.title('\n Random Forest Accuracy Against \n Features Graph of each classifier')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(3,2,6)
plt.plot(df_sig['features'], df_sig['rt_ig'], c='red', label='InfoGain')
plt.plot(df_sig['features'], df_sig['rt_cr'], c='green', label='Correlation')
plt.plot(df_sig['features'], df_sig['rt_rff'], c='blue', label='Relief')
plt.plot(df_sig['features'], df_sig['rt_gr'], c='orange', label='Gain Ratio')
plt.plot(df_sig['features'], df_sig['rt_chi'], c='yellow', label='Chi Square')
plt.title('\n Random Tree Accuracy Against \n Features Graph of each classifier')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
df_graph = pd.read_csv('D:\\desktop files\\weka\\Datasets\\HAPT Data Set\\uci_4fts_selectors\\classifier_ft_selectors.csv')
df_graph
# Out:
#                      CLASSIFIERS  ORIGINAL DATA  AFTER RELIEF  \
# 0                       BAYESNET           79.5          86.0
# 1                            KNN           96.1          95.8
# 2  CLASSIFICATION VIA REGRESSION           96.0          95.6
# 3                            J48           93.0          93.6
# 4                  RANDOM FOREST           96.8          96.8
# 5                    RANDOM TREE           86.6          91.3
#
#    AFTER INFO GAIN  AFTER GAIN RATION  AFTER CORRELATION  AFTER CHI SQUARE
# 0             79.9               56.5               59.1              82.4
# 1             92.2               93.2               86.9              94.6
# 2             93.1               83.6               86.1              95.1
# 3             90.9               77.0               79.9              92.8
# 4             94.5               86.1               88.4              95.3
# 5             87.4               69.9               75.2              89.0

# %%
con = {'ft': [9,8,7,6,5,4,3,2,1],
        'a': [92.5,85.3,80.1,68.9,75.0,71.5,69.0,57.0,34.3]
       } 
con_df = pd.DataFrame(con,columns=['ft','a'])

# %%
plt.figure(figsize=(10, 7))
plt.subplot(2,3,1)
plt.plot(con_df['ft'], con_df['a'], c='red', label='Consistency')
plt.title('Decision Tree Accuracy Against Features Graph')
plt.xlabel('Number Of Features')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f804fdb5bece> in <module>
#       1 plt.figure(figsize=(10, 7))
#       2 plt.subplot(2,3,1)
# ----> 3 plt.plot(con_df['ft'], con_df['a'], c='red', label='Consistency')
#       4 plt.title('Decision Tree Accuracy Against Features Graph')
#       5 plt.xlabel('Number Of Features')
#
# NameError: name 'con_df' is not defined
